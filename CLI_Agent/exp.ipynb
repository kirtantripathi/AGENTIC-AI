# %%
from langchain_community.tools import ShellTool

# %%
s = ShellTool()
s.invoke(input={"commands":['dir']})
# Out:
# Executing command:
#  ['dir']
# ' Volume in drive C has no label.\r\n Volume Serial Number is 6842-61A2\r\n\r\n Directory of c:\\Users\\Kirtan Tripathi\\OneDrive - HUBBROKER ApS\\Desktop\\cli_file_system_agent\r\n\r\n04/02/2026  12:57 PM    <DIR>          .\r\n04/02/2026  12:57 PM    <DIR>          ..\r\n04/02/2026  12:54 PM             7,042 agent.py\r\n04/02/2026  01:09 PM             1,362 exp.ipynb\r\n04/02/2026  01:00 PM    <DIR>          my_env\r\n04/02/2026  12:55 PM             3,572 tools.py\r\n04/02/2026  12:55 PM    <DIR>          __pycache__\r\n               3 File(s)         11,976 bytes\r\n               4 Dir(s)  51,867,070,464 bytes free\r\n'
